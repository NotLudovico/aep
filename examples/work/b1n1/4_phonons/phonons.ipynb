# %%
from abipy.abilab import abiopen

# %%
with abiopen("./outdata/3_anaddb/anaddb_PHBST.nc") as ncfile:
    phbands = ncfile.phbands
with abiopen("./outdata/3_anaddb/anaddb_PHDOS.nc") as ncfile:
    phdos = ncfile.phdos
# Out:
# /home/mcagnoni/.local/opt/conda/envs/cf.abipy/lib/python3.10/site-packages/pymatgen/symmetry/kpath.py:183: UserWarning: The input structure does not match the expected standard primitive! The path may be incorrect. Use at your own risk.
#   warn(

# %%
fig = phbands.plot_with_phdos(phdos, units="cm-1")
fig.savefig("figures/phonons.pdf", dpi=300)
